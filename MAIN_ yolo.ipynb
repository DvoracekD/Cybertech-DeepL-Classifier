# %%
from GenerateSyntheticDataset import generate_dataset
import os
import shutil
from distutils.dir_util import copy_tree
import time

# %% [markdown]
# ### Setup variables for the run

# %%
GENERATE_NEW = True  # fail-safe so we don't overwrite our dataset
GENERATE_NR_IMAGES = 220
SEGMENTATION = True
GENERATE_VIDEO = True
results = {'Mode': 'Segmentation' if SEGMENTATION else 'Detection'}

# %%
if GENERATE_NEW:
    #check if "/datasets" exists, if it does, delete it
    if os.path.isdir("./datasets"):
        print("Deleting old dataset...")
        #remove the old dataset
        for filename in os.listdir("./datasets"):
            file_path = os.path.join("./datasets", filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print('Failed to delete %s. Reason: %s' % (file_path, e))

    generate_dataset(custom_num_images=GENERATE_NR_IMAGES, segmentation=SEGMENTATION)

    os.makedirs("./datasets", exist_ok=True)
    copy_tree("./GeneratedDataset/", "./datasets/GeneratedDataset")

# %% [markdown]
# ### Video generation from images

# %%
if GENERATE_VIDEO:
    import cv2
    import os
    
    image_folder = 'real_footage/Run1/color'
    video_name = 'real_footage/Run1/run1.mp4'
    
    images = [img for img in os.listdir(image_folder) if img.endswith(".png")]
    images.sort()
    frame = cv2.imread(os.path.join(image_folder, images[0]))
    height, width, layers = frame.shape
    
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    
    video = cv2.VideoWriter(video_name, fourcc, 20.0, (width, height))
    
    for image in images:
        video.write(cv2.imread(os.path.join(image_folder, image)))
    
    video.release()

# %% [markdown]
# ## Object detection

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/
# Out:
# Launching TensorBoard...

# %%
if not SEGMENTATION:
    from ultralytics import YOLO
    import torch
    import platform
    
    # Load already trained weights
    
    ###########
    EPOCHS = 30
    model_to_use = 'runs/detect/train5/weights/best.pt'  # use 'yolov8n.pt' to start fresh
    ###########
    
    #if windows put "/" before model_to_use 
    curr_os = platform.system()
    if curr_os == 'Windows':
        model_to_use = '/' + model_to_use
    
    try:
        model = YOLO(model_to_use)
    except FileNotFoundError:
        print("Model not found, retraining from scratch with YoloV8n")
        model = YOLO('yolov8n.pt')
    
    #check if using cuda
    if torch.cuda.is_available():
        print("Using GPU")
        model.cuda()
    
    #is os windows?
    import os
    import platform
    
    start = time.time()
    if curr_os == 'Windows':
        print('Using Windows')
        results = model.train(data='generated_dataset_Win.yaml', epochs=EPOCHS)
    else:
        print('Using Linux')
        results = model.train(data='generated_dataset.yaml', epochs=EPOCHS)
    end = time.time()
    
    # Save the results
    results['Epochs'] = EPOCHS
    results['Time training'] = end - start

# %% [markdown]
# ## Segmentation

# %%
if SEGMENTATION:
    from ultralytics import YOLO
    import torch
    import platform
    
    # Load already trained weights
    
    ###########
    EPOCHS = 50
    BATCH_SIZE = 8
    TRAIN = True
    model_to_use = 'runs/segment/train13/weights/best.pt'  # use 'yolov8n-seg.pt' to start fresh
    ###########
    
    #if windows put "/" before model_to_use 
    curr_os = platform.system()
    if curr_os == 'Windows':
        model_to_use = '/' + model_to_use
    
    try:
        model = YOLO(model_to_use)
    except FileNotFoundError:
        print("Model not found, retraining from scratch with YoloV8n-seg")
        model = YOLO('yolov8n-seg.pt')
    
    #check if using cuda
    if torch.cuda.is_available():
        print("Using GPU")
        model.cuda()
    
    #is os windows?
    import os
    import platform
    
    if TRAIN:
        start = time.time()
        if curr_os == 'Windows':
            print('Using Windows')
            results = model.train(data='generated_dataset_Win.yaml', epochs=EPOCHS, batch=BATCH_SIZE)
        else:
            print('Using Linux')
            results = model.train(data='generated_dataset.yaml', epochs=EPOCHS, batch=BATCH_SIZE)
        end = time.time()
        results['Time training'] = end - start
    # Save the results
    results['Epochs'] = EPOCHS
# Out:
# Using GPU

# %% [markdown]
# ## Export results

# %%
# Create folder for results
if not os.path.isdir('./results'):
    os.makedirs('./results')
# Save results in txt file
with open("results/results.txt", 'w') as f:  
    for key, value in results.items():  
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# ### Random image result

# %%
from PIL import Image

results = model('real_footage/Run1/color/000056.png')  # results list

# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
    im.save('results/results.jpg')  # save image
# Out:
# image 1/1 /home/misarond/DTU/Cybertech-DeepL-Classifier/real_footage/Run1/color/000056.png: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 19.7ms
# Speed: 1.8ms preprocess, 19.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Real footage video result

# %%
import cv2
import time

# Get the image shape
frame = cv2.imread('real_footage/Run1/color/000000.png')
height, width, layers = frame.shape

# Open the video file
video_path = "real_footage/Run1/run1.mp4"
cap = cv2.VideoCapture(video_path)
img_array = []

# used to record the time when we processed last frame 
prev_frame_time = 0
# used to record the time at which we processed current frame 
new_frame_time = 0

font = cv2.FONT_HERSHEY_SIMPLEX
bottomLeftCornerOfText = (1750, 25)
fontScale = 1
fontColor = (0, 0, 255)
thickness = 2
lineType = 2

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()
        
        # time when we finish processing for this frame 
        new_frame_time = time.time()

        # fps will be number of frame processed in given time frame 
        # since their will be the most time error of 0.001 second 
        # we will be subtracting it to get more accurate result 
        fps = 1 / (new_frame_time - prev_frame_time)
        prev_frame_time = new_frame_time

        # converting the fps into integer 
        fps = str(int(fps))

        # putting the FPS count on the frame 
        cv2.putText(annotated_frame, 'FPS: ' + fps,
                    bottomLeftCornerOfText,
                    font,
                    fontScale,
                    fontColor,
                    thickness,
                    lineType)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)
        img_array.append(annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

out = cv2.VideoWriter('results/real_footage.mp4', cv2.VideoWriter_fourcc(*'XVID'), 30.0,
                      (width, height))
#write video
for i in range(len(img_array)):
    out.write(img_array[i])
out.release()
print('Video created successfully.')
# Out:
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 2 mouthwashs, 1 toothpaste, 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 2 mouthwashs, 1 toothpaste, 20.8ms
# Speed: 3.6ms preprocess, 20.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 2 mouthwashs, 1 toothpaste, 20.9ms
# Speed: 3.2ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 2 mouthwashs, 1 toothpaste, 19.2ms
# Speed: 2.5ms preprocess, 19.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 2 mouthwashs, 1 toothpaste, 19.2ms
# Speed: 2.5ms preprocess, 19.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 stainremover, 1 toothpaste, 19.0ms
# Speed: 2.9ms preprocess, 19.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 stainremover, 1 toothpaste, 20.0ms
# Speed: 2.6ms preprocess, 20.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 stainremover, 1 toothpaste, 19.1ms
# Speed: 2.6ms preprocess, 19.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 stainremover, 1 toothpaste, 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 19.2ms
# Speed: 3.2ms preprocess, 19.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 18.9ms
# Speed: 2.4ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.5ms
# Speed: 2.6ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.6ms
# Speed: 2.7ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.0ms
# Speed: 2.7ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 17.1ms
# Speed: 3.1ms preprocess, 17.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.4ms
# Speed: 2.4ms preprocess, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.4ms
# Speed: 2.8ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 2.8ms preprocess, 15.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.2ms
# Speed: 3.3ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.4ms
# Speed: 2.2ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.8ms
# Speed: 3.2ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.8ms
# Speed: 2.9ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.9ms
# Speed: 3.7ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.0ms
# Speed: 2.7ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.8ms
# Speed: 3.2ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.6ms
# Speed: 3.1ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.1ms
# Speed: 2.6ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 3.0ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.5ms
# Speed: 2.6ms preprocess, 16.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.5ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 19.8ms
# Speed: 2.9ms preprocess, 19.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 2.7ms preprocess, 15.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.1ms
# Speed: 2.6ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 16.9ms
# Speed: 1.9ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.0ms
# Speed: 2.3ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 14.5ms
# Speed: 2.6ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 16.7ms
# Speed: 2.6ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 stainremover, 1 toothpaste, 17.0ms
# Speed: 2.7ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 showergel, 1 stainremover, 1 toothpaste, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 mouthwash, 1 showergel, 1 stainremover, 1 toothpaste, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 stainremover, 1 toothpaste, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 stainremover, 1 toothpaste, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 showergel, 1 stainremover, 2 toothpastes, 13.8ms
# Speed: 2.6ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 showergel, 1 stainremover, 2 toothpastes, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 3 toothpastes, 13.8ms
# Speed: 2.7ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 stainremover, 3 toothpastes, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 showergel, 3 toothpastes, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 2 ketchups, 1 showergel, 1 toothpaste, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 2 toothpastes, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 showergel, 1 toothpaste, 16.6ms
# Speed: 2.8ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 showergel, 1 toothpaste, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 toothpaste, 16.4ms
# Speed: 2.5ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 2 catfoods, 1 ketchup, 1 showergel, 1 toothpaste, 16.6ms
# Speed: 2.7ms preprocess, 16.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 ketchup, 1 showergel, 1 toothpaste, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 showergel, 1 toothpaste, 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 showergel, 1 toothpaste, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 banana, 1 catfood, 1 showergel, 1 toothpaste, 1 trex, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 showergel, 1 toothpaste, 1 trex, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 showergel, 1 toothpaste, 2 trexs, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 showergel, 1 toothpaste, 2 trexs, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 showergel, 1 toothpaste, 2 trexs, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.1ms
# Speed: 3.1ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 16.4ms
# Speed: 2.6ms preprocess, 16.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 16.9ms
# Speed: 2.4ms preprocess, 16.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 toothpaste, 15.9ms
# Speed: 3.1ms preprocess, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 15.2ms
# Speed: 2.7ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 toothpaste, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 1 toothpaste, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 showergel, 1 toothpaste, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 showergel, 2 toothpastes, 15.3ms
# Speed: 2.6ms preprocess, 15.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 toothpaste, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 toothpaste, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 1 ketchup, 1 toothpaste, 14.2ms
# Speed: 1.8ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 catfood, 2 ketchups, 1 showergel, 14.1ms
# Speed: 1.8ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 catfoods, 1 ketchup, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trexs, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ketchup, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Video created successfully.
